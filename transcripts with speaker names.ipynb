# %% [markdown]
# Notes on usage:
#
# - Make sure to [change runtime to GPU](https://www.tutorialspoint.com/google_colab/google_colab_using_free_gpu.htm).
# - The transcript will be saved in Files, which you can find in the menu on the left.
# - Change the number of speakers below if different from two.
# - Pick a bigger model if you want more accuracy and a smaller model if you want the program to run faster ([more info](https://github.com/openai/whisper#available-models-and-languages)).
# - If you know the language being spoken is English, then change language to 'English' as this improves performance.
#
#
# High level overview of what's happening here:
#
#
# 1.   I'm using Open AI's Whisper model to seperate audio into segments and generate transcripts.
# 2.   I'm then generating speaker embeddings for each segments.
# 3.   Then I'm using agglomerative clustering on the embeddings to identify the speaker for each segment.
#
# Let me know if I can make it better!

# %%
uploaded=None

# %%
# upload audio file
from google.colab import files
uploaded = files.upload()
path = next(iter(uploaded))
# Out:
#      <input type="file" id="files-8235a0ff-dfea-413b-b2dc-04a24172d3f3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8235a0ff-dfea-413b-b2dc-04a24172d3f3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
num_speakers = 3 #@param {type:"integer"}

language = 'any' #@param ['any', 'English']

model_size = 'large' #@param ['tiny', 'base', 'small', 'medium', 'large']


model_name = model_size
if language == 'English' and model_size != 'large':
  model_name += '.en'

# %%
# !pip install -q git+https://github.com/openai/whisper.git > /dev/null
# !pip install -q git+https://github.com/pyannote/pyannote-audio > /dev/null

# %%
import whisper
import datetime

import subprocess

import torch
import pyannote.audio
from pyannote.audio.pipelines.speaker_verification import PretrainedSpeakerEmbedding

embedding_model = PretrainedSpeakerEmbedding(
    "speechbrain/spkrec-ecapa-voxceleb",
    device=torch.device("cuda"), use_auth_token="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")

from pyannote.audio import Audio
from pyannote.core import Segment

import wave
import contextlib

from sklearn.cluster import AgglomerativeClustering
import numpy as np
# Out:
# /usr/local/lib/python3.10/dist-packages/pyannote/audio/core/io.py:43: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")
# /usr/local/lib/python3.10/dist-packages/torch_audiomentations/utils/io.py:27: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")

# %%
model = whisper.load_model(model_size)

# %%
uploaded = '/content/Lula_1.mp3' if not uploaded else uploaded
path = next(iter(uploaded))
print(path)
if path[-3:] != 'wav':
  subprocess.call(['ffmpeg', '-i', path, '-ac', '1', '-ar', ' 16000', 'audio.wav', '-y'])
  path = 'audio.wav'
# Out:
# Neymar_0.mp3

# %%
result = model.transcribe(path)
segments = result["segments"]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-fd8fc83b04ec> in <cell line: 1>()
# ----> 1 result = model.transcribe(path)
#       2 segments = result["segments"]
#
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py in transcribe(model, audio, verbose, temperature, compression_ratio_threshold, logprob_threshold, no_speech_threshold, condition_on_previous_text, initial_prompt, word_timestamps, prepend_punctuations, append_punctuations, **decode_options)
#     238
#     239             decode_options["prompt"] = all_tokens[prompt_reset_since:]
# --> 240             result: DecodingResult = decode_with_fallback(mel_segment)
#     241             tokens = torch.tensor(result.tokens)
#     242
#
# /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py in decode_with_fallback(segment)
#     168
# ...

# %%
with contextlib.closing(wave.open(path,'r')) as f:
  frames = f.getnframes()
  rate = f.getframerate()
  duration = frames / float(rate)

# %%
audio = Audio()

def segment_embedding(segment):
  start = segment["start"]
  # Whisper overshoots the end timestamp in the last segment
  end = min(duration, segment["end"])
  clip = Segment(start, end)
  waveform, sample_rate = audio.crop(path, clip)
  return embedding_model(waveform[None])

# %%
embeddings = np.zeros(shape=(len(segments), 192))
for i, segment in enumerate(segments):
  embeddings[i] = segment_embedding(segment)

embeddings = np.nan_to_num(embeddings)

# %%
clustering = AgglomerativeClustering(num_speakers).fit(embeddings)
labels = clustering.labels_
for i in range(len(segments)):
  segments[i]["speaker"] = 'SPEAKER ' + str(labels[i] + 1)

# %%
def time(secs):
  return datetime.timedelta(seconds=round(secs))

f = open("transcript.txt", "w")
times = open("timestamps.txt", "w")
start = "0:0:0"
for (i, segment) in enumerate(segments):
  if i == 0 or segments[i - 1]["speaker"] != segment["speaker"]:
    #Getting start and end
    end = str(time(segments[i-1]["end"]))
    if i != 0:
      times.write("\n" + segments[i-1]["speaker"] + '\t' + start + '\t' + end)
    start = str(time(segment["start"]))

    f.write("\n" + segment["speaker"] + ' ' + str(time(segment["start"])) + '\n')
  f.write(segment["text"][1:] + ' ')
f.close()
times.close()
